# %%
import pandas as pd 
import numpy as np 
import json
import requests

# %%
pip install tmdbv3api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from tmdbv3api import TMDb

# %%
url = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
content1 = pd.read_html(url, header=0)[2]
content2 = pd.read_html(url, header=0)[3]
content3 = pd.read_html(url, header=0)[4]
content4 = pd.read_html(url, header=0)[5]

# %%
content = content1.append(content2.append(content3.append(content4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
content.head()
# Out:
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                                  Momentum Pictures
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew  \
# 0  Adam Robitel (director); Leigh Whannell (scree...
# 1  Lauren Wolkstein (director); Christopher Radcl...
# 2  Simon West (director); Duncan Falconer, Warren...
# 3  Warwick Thornton (director); David Tranter, St...
# 4  Jaume Collet-Serra (director); Byron Willinger...
#
# ...

# %%
content.shape
# Out:
# (272, 7)

# %%
tmdb = TMDb()
tmdb.api_key = '2946819469ace2bf8ccde8b306d41888'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def source_genre(title):
    genres = []
    result = tmdb_movie.search(title)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
content['Genre'] = content['Title'].map(lambda x: source_genre(str(x)))

# %%
content.head()
# Out:
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                                  Momentum Pictures
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew  \
# 0  Adam Robitel (director); Leigh Whannell (scree...
# 1  Lauren Wolkstein (director); Christopher Radcl...
# 2  Simon West (director); Duncan Falconer, Warren...
# 3  Warwick Thornton (director); David Tranter, St...
# 4  Jaume Collet-Serra (director); Byron Willinger...
#
# ...

# %%
content.drop('Ref.',axis=1, inplace=True)

# %%
content
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
content.rename(columns = {'.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.':'Ref.'}, inplace = True)

# %%
content.head()
# Out:
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                                  Momentum Pictures
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew Ref.  \
# 0  Adam Robitel (director); Leigh Whannell (scree...  [2]
# 1  Lauren Wolkstein (director); Christopher Radcl...  [3]
# 2  Simon West (director); Duncan Falconer, Warren...  [4]
# 3  Warwick Thornton (director); David Tranter, St...  [5]
# 4  Jaume Collet-Serra (director); Byron Willinger...  [6]
#
# ...

# %%
content_2018 = content[['Title','Cast and crew','Genre']]

# %%
content_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                      Genre
# 0  Horror Mystery Thriller
# 1           Thriller Drama
# 2          Action Thriller
# 3    Drama History Western
# 4  Action Thriller Mystery

# %%
content_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
content_2018.tail()
# Out:
#                           Title  \
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#                                                Genre
# 267                   Mystery Adventure Comedy Crime
# 268        Thriller Science Fiction Action Adventure
# 269                                    Drama History
# 270                      Thriller Crime Drama Action
# 271  Science Fiction Mystery Drama Thriller TV Movie

# %%
def director(title):
  if " (director)" in title:
    return title.split(" (director)")[0]
  elif " (directors)" in title:
    return title.split(" (directors)")[0]
  else:
    return title.split(" (director/screenplay)")[0]

# %%
content_2018['director'] = content_2018['Cast and crew'].map(lambda x: director(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def actor1(x):
   return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
content_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                      Genre            director
# 0  Horror Mystery Thriller        Adam Robitel
# 1           Thriller Drama    Lauren Wolkstein
# 2          Action Thriller          Simon West
# 3    Drama History Western    Warwick Thornton
# 4  Action Thriller Mystery  Jaume Collet-Serra

# %%
content_2018['actor 1'] = content_2018['Cast and crew'].map(lambda x: actor1(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def actor2(x):
   if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
   else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
content_2018['actor 2'] = content_2018['Cast and crew'].map(lambda x: actor2(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def actor3(x):
   if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
   else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
content_2018['actor 3'] = content_2018['Cast and crew'].map(lambda x: actor3(x))

# %%
content_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                      Genre            director         actor 1  \
# 0  Horror Mystery Thriller        Adam Robitel       Lin Shaye
# 1           Thriller Drama    Lauren Wolkstein   Alex Pettyfer
# 2          Action Thriller          Simon West  Dominic Cooper
# 3    Drama History Western    Warwick Thornton     Bryan Brown
# 4  Action Thriller Mystery  Jaume Collet-Serra     Liam Neeson
#
#                   actor 2         actor 3
# 0           Angus Sampson  Leigh Whannell
# ...

# %%
content_2018.shape
# Out:
# (272, 7)

# %%
content_2018.drop('Cast and crew',axis=1, inplace=True)

# %%
content_2018.head()
# Out:
#                      Title                    Genre            director  \
# 0  Insidious: The Last Key  Horror Mystery Thriller        Adam Robitel
# 1         The Strange Ones           Thriller Drama    Lauren Wolkstein
# 2                 Stratton          Action Thriller          Simon West
# 3            Sweet Country    Drama History Western    Warwick Thornton
# 4             The Commuter  Action Thriller Mystery  Jaume Collet-Serra
#
#           actor 1                 actor 2         actor 3
# 0       Lin Shaye           Angus Sampson  Leigh Whannell
# 1   Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2  Dominic Cooper          Austin Stowell      Gemma Chan
# 3     Bryan Brown               Sam Neill             NaN
# 4     Liam Neeson            Vera Farmiga  Patrick Wilson

# %%
new_content_2018 = content_2018.loc[:,['director','actor 1','actor 2','actor 3','Genre','Title']]

# %%
new_content_2018
# Out:
#                director          actor 1                 actor 2  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#             actor 3                                            Genre  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %%
new_content_2018.isnull().sum()
# Out:
# director    0
# actor 1     0
# actor 2     0
# actor 3     0
# Genre       0
# Title       0
# combo       0
# dtype: int64

# %%
new_content_2018['actor 2'] = content_2018['actor 2'].replace(np.nan , 'unknown')
new_content_2018['actor 3'] = content_2018['actor 3'].replace(np.nan , 'unknown')
new_content_2018['Genre'] = content_2018['Genre'].replace(np.nan , 'unknown')

# %%
new_content_2018['combo'] = content_2018['actor 1'] + content_2018['actor 2'] + ' ' + content_2018['actor 3'] + ' ' + content_2018['director'] + ' ' + content_2018['Genre']

# %%
new_content_2018
# Out:
#                director          actor 1                 actor 2  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#             actor 3                                            Genre  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %%
url = 'https://en.wikipedia.org/wiki/List_of_American_films_of_2019'

# %%
content1 = pd.read_html(url, header=0)[2]
content2 = pd.read_html(url, header=0)[3]
content3 = pd.read_html(url, header=0)[4]
content4 = pd.read_html(url, header=0)[5]

# %%
content = content = content1.append(content2.append(content3.append(content4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
content.head()
# Out:
#    Opening  Opening.1             Title                 Production company  \
# 0  JANUARY          4       Escape Room  Columbia Pictures / Original Film
# 1  JANUARY          4        Rust Creek                          IFC Films
# 2  JANUARY          4  American Hangman        Hangman Justice Productions
# 3  JANUARY         11  A Dog's Way Home                  Columbia Pictures
# 4  JANUARY         11        The Upside                  STX Entertainment
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]
# 4  Neil Burger (director); Jon Hartmere (screenpl...  [6]

# %%
content['Genre'] = content['Title'].map(lambda x: source_genre(str(x)))

# %%
content.head()
# Out:
#    Opening  Opening.1             Title                 Production company  \
# 0  JANUARY          4       Escape Room  Columbia Pictures / Original Film
# 1  JANUARY          4        Rust Creek                          IFC Films
# 2  JANUARY          4  American Hangman        Hangman Justice Productions
# 3  JANUARY         11  A Dog's Way Home                  Columbia Pictures
# 4  JANUARY         11        The Upside                  STX Entertainment
#
#                                        Cast and crew Ref.  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]
# 4  Neil Burger (director); Jon Hartmere (screenpl...  [6]
#
#                     Genre
# 0  Horror Comedy Thriller
# 1          Thriller Drama
# 2                Thriller
# 3  Drama Adventure Family
# 4            Comedy Drama

# %%
content_2019 = content[['Title', 'Cast and crew', 'Genre' ]]

# %%
content_2019.head()
# Out:
#               Title                                      Cast and crew  \
# 0       Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1        Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2  American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3  A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4        The Upside  Neil Burger (director); Jon Hartmere (screenpl...
#
#                     Genre
# 0  Horror Comedy Thriller
# 1          Thriller Drama
# 2                Thriller
# 3  Drama Adventure Family
# 4            Comedy Drama

# %%
def director(title):
  if "(director)" in title:
    return title.split("(director)")[0]
  elif "(directors)" in title:
    return title.split("(directors)")[0]
  else:
    return title.split("(director/screenplay)")[0]

# %%
content_2019['director'] = content_2019['Cast and crew'].map(lambda x: director(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
content_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 237  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 238       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 239               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 240         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 241           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                         Genre                 director
# ...

# %%
def actor1(x):
   return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
content_2019['actor 1'] = content_2019['Cast and crew'].map(lambda x: actor1(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
content_2019['actor 2'] = content_2019['Cast and crew'].map(lambda x: actor2(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
content_2019['actor 3'] = content_2019['Cast and crew'].map(lambda x: actor3(x))

# %%
  content_2019.isnull().sum()
# Out:
# Title             0
# Cast and crew     0
# Genre             0
# director          0
# actor 1           0
# actor 2           1
# actor 3          15
# dtype: int64

# %%
content_2019['actor 2'] = content_2019['actor 2'].replace(np.nan, 'unknown')

# %%
content_2019['actor 3'] = content_2019['actor 3'].replace(np.nan, 'unknown')

# %%
content_2019.head()
# Out:
#               Title                                      Cast and crew  \
# 0       Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1        Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2  American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3  A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4        The Upside  Neil Burger (director); Jon Hartmere (screenpl...
#
#                     Genre               director              actor 1  \
# 0  Horror Comedy Thriller          Adam Robitel        Taylor Russell
# 1          Thriller Drama           Jen McGowan     Hermione Corfield
# 2                Thriller     Wilson Coneybeare     Donald Sutherland
# 3  Drama Adventure Family  Charles Martin Smith   Bryce Dallas Howard
# 4            Comedy Drama           Neil Burger        Bryan Cranston
#
#               actor 2           actor 3
# 0        Logan Miller  Deborah Ann Woll
# ...

# %%
new_content_2019 = content_2019.loc[:,['director', 'actor 1', 'actor 2', 'actor 3', 'Genre', 'Title']]

# %%
new_content_2019.tail()
# Out:
#                     director            actor 1               actor 2  \
# 237  Nick Bruno, Troy Quane          Will Smith           Tom Holland
# 238            Greta Gerwig       Saoirse Ronan           Emma Watson
# 239              Sam Mendes       George MacKay  Dean-Charles Chapman
# 240   Destin Daniel Cretton   Michael B. Jordan            Jamie Foxx
# 241         Chinonye Chukwu       Alfre Woodard        Wendell Pierce
#
#            actor 3                                     Genre  \
# 237  Rashida Jones  Animation Action Adventure Comedy Family
# 238  Florence Pugh                             Drama Romance
# 239    Mark Strong         War Drama Action Thriller History
# 240    Brie Larson                       Drama Crime History
# 241    Aldis Hodge                                     Drama
#
#                  Title
# 237  Spies in Disguise
# 238       Little Women
# 239               1917
# 240         Just Mercy
# 241           Clemency

# %%
new_content_2019['combo'] = content_2019['actor 1'] + content_2019['actor 2'] + ' ' + content_2019['actor 3'] + ' ' + content_2019['director'] + ' ' + content_2019['Genre']

# %%
new_content_2019
# Out:
#                     director              actor 1               actor 2  \
# 0              Adam Robitel        Taylor Russell          Logan Miller
# 1               Jen McGowan     Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare     Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith   Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger        Bryan Cranston            Kevin Hart
# ..                       ...                  ...                   ...
# 237  Nick Bruno, Troy Quane            Will Smith           Tom Holland
# 238            Greta Gerwig         Saoirse Ronan           Emma Watson
# 239              Sam Mendes         George MacKay  Dean-Charles Chapman
# 240   Destin Daniel Cretton     Michael B. Jordan            Jamie Foxx
# 241         Chinonye Chukwu         Alfre Woodard        Wendell Pierce
#
#               actor 3                                     Genre  \
# ...

# %%
content_18_19 = new_content_2018.append(new_content_2019, ignore_index = True
                                      )

# %%
content_18_19
# Out:
#                     director            actor 1                 actor 2  \
# 0               Adam Robitel          Lin Shaye           Angus Sampson
# 1           Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2                 Simon West     Dominic Cooper          Austin Stowell
# 3           Warwick Thornton        Bryan Brown               Sam Neill
# 4         Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                       ...                ...                     ...
# 509  Nick Bruno, Troy Quane          Will Smith             Tom Holland
# 510            Greta Gerwig       Saoirse Ronan             Emma Watson
# 511              Sam Mendes       George MacKay    Dean-Charles Chapman
# 512   Destin Daniel Cretton   Michael B. Jordan              Jamie Foxx
# 513         Chinonye Chukwu       Alfre Woodard          Wendell Pierce
#
#             actor 3                                     Genre  \
# ...

# %%
content_17 = pd.read_csv('/content/content_2017.csv')

# %%
content_17
# Out:
#       Unnamed: 0               director               actor 1  \
# 0              0          James Cameron           CCH Pounder
# 1              1         Gore Verbinski           Johnny Depp
# 2              2             Sam Mendes       Christoph Waltz
# 3              3      Christopher Nolan             Tom Hardy
# 4              4            Doug Walker           Doug Walker
# ...          ...                    ...                   ...
# 5359        5359            Jim Strouse      Jessica Williams
# 5360        5360            Farhad Mann         Adelaide Kane
# 5361        5361       Hannaleena Hauru        Inka Haapamäki
# 5362        5362  Jonathan A. Rosenbaum  Lou Diamond Phillips
# 5363        5363           Ravi Udyawar        Sridevi Kapoor
#
#                      actor 2               actor 3  \
# 0           Joel David Moore             Wes Studi
# 1              Orlando Bloom        Jack Davenport
# 2               Rory Kinnear      Stephanie Sigman
# ...

# %%
content_17.rename(columns = {'combo 1':'combo',}, inplace = True)

# %%
content_17
# Out:
#                    director               actor 1                 actor 2  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#                    actor 3                            Genre  \
# ...

# %%
new_content = content_17.append(content_18_19,ignore_index=True)

# %%
new_content
# Out:
#                      director            actor 1               actor 2  \
# 0               James Cameron        CCH Pounder      Joel David Moore
# 1              Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                  Sam Mendes    Christoph Waltz          Rory Kinnear
# 3           Christopher Nolan          Tom Hardy        Christian Bale
# 4                 Doug Walker        Doug Walker            Rob Walker
# ...                       ...                ...                   ...
# 5873  Nick Bruno, Troy Quane          Will Smith           Tom Holland
# 5874            Greta Gerwig       Saoirse Ronan           Emma Watson
# 5875              Sam Mendes       George MacKay  Dean-Charles Chapman
# 5876   Destin Daniel Cretton   Michael B. Jordan            Jamie Foxx
# 5877         Chinonye Chukwu       Alfre Woodard        Wendell Pierce
#
#                    actor 3                                     Genre  \
# ...

# %%
new_content.isna().sum()
# Out:
# director    0
# actor 1     0
# actor 2     0
# actor 3     0
# Genre       0
# Title       0
# combo       0
# dtype: int64

# %%
new_content.to_csv('processed_17_18_19.csv')
